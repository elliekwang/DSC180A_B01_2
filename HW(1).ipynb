# %% [markdown]
# # Prism Data

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
inflows = pd.read_parquet('/uss/hdsi-prismdata/q1-ucsd-inflows.pqt')

# %%
outflows = pd.read_parquet('/uss/hdsi-prismdata/q1-ucsd-outflows.pqt')

# %%
inflows.head(5)
# Out:
#    prism_consumer_id prism_account_id               memo   amount posted_date  \
# 0                  0            acc_0           PAYCHECK  2477.02  2022-03-18
# 1                  0            acc_0  EXTERNAL_TRANSFER   100.00  2022-10-25
# 2                  0            acc_0      MISCELLANEOUS     6.29  2022-08-26
# 3                  0            acc_0  EXTERNAL_TRANSFER   277.00  2022-06-03
# 4                  0            acc_0  EXTERNAL_TRANSFER   100.00  2022-07-29
#
#             category
# 0           PAYCHECK
# 1  EXTERNAL_TRANSFER
# 2      MISCELLANEOUS
# 3  EXTERNAL_TRANSFER
# 4  EXTERNAL_TRANSFER

# %%
outflows.head(5)
# Out:
#    prism_consumer_id prism_account_id  \
# 0                  0            acc_0
# 1                  0            acc_0
# 2                  0            acc_0
# 3                  0            acc_0
# 4                  0            acc_0
#
#                                         memo  amount posted_date  \
# 0                                       LOAN  900.60  2022-07-05
# 1                                   ATM_CASH   80.00  2022-03-25
# 2  TST* Casa Del Rio - Exp Fairlawn OH 09/24   18.42  2022-09-26
# 3                                       LOAN  634.00  2023-01-10
# 4                         Buffalo Wild Wings   26.47  2022-09-12
#
#              category
# 0                LOAN
# 1            ATM_CASH
# 2  FOOD_AND_BEVERAGES
# 3                LOAN
# 4  FOOD_AND_BEVERAGES

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# *inflows*

# %%
inflows['prism_consumer_id'].nunique()
# Out:
# 2974

# %%
inflows['memo'].value_counts()
# Out:
# memo
# EXTERNAL_TRANSFER        156533
# SELF_TRANSFER            110437
# DEPOSIT                   61345
# MISCELLANEOUS             55648
# PAYCHECK                  33138
# PAYCHECK_PLACEHOLDER      26087
# REFUND                    23220
# INVESTMENT_INCOME         17325
# SMALL_DOLLAR_ADVANCE      13621
# OTHER_BENEFITS             7708
# TAX                        3405
# LOAN                       2513
# UNEMPLOYMENT_BENEFITS      1961
# INSURANCE                   174
# Name: count, dtype: int64

# %%
inflows[inflows['memo'] == inflows['category']]
# Out:
#         prism_consumer_id prism_account_id               memo   amount  \
# 0                       0            acc_0           PAYCHECK  2477.02
# 1                       0            acc_0  EXTERNAL_TRANSFER   100.00
# 2                       0            acc_0      MISCELLANEOUS     6.29
# 3                       0            acc_0  EXTERNAL_TRANSFER   277.00
# 4                       0            acc_0  EXTERNAL_TRANSFER   100.00
# ...                   ...              ...                ...      ...
# 513110               5941         acc_9524  EXTERNAL_TRANSFER     8.66
# 513111               5941         acc_9524  EXTERNAL_TRANSFER   267.13
# 513112               5941         acc_9524  EXTERNAL_TRANSFER     2.00
# 513113               5941         acc_9524  EXTERNAL_TRANSFER   207.16
# 513114               5941         acc_9524  EXTERNAL_TRANSFER   281.71
#
#        posted_date           category
# 0       2022-03-18           PAYCHECK
# 1       2022-10-25  EXTERNAL_TRANSFER
# 2       2022-08-26      MISCELLANEOUS
# 3       2022-06-03  EXTERNAL_TRANSFER
# 4       2022-07-29  EXTERNAL_TRANSFER
# ...            ...                ...
# 513110  2023-01-21  EXTERNAL_TRANSFER
# 513111  2023-01-23  EXTERNAL_TRANSFER
# 513112  2023-01-24  EXTERNAL_TRANSFER
# 513113  2023-01-24  EXTERNAL_TRANSFER
# 513114  2023-01-25  EXTERNAL_TRANSFER
#
# [513115 rows x 6 columns]

# %%
len(inflows)
# Out:
# 513115

# %%
inflows['memo'].nunique()
# Out:
# 14

# %%
inflows['category'].nunique()
# Out:
# 14

# %% [markdown]
# **Number of unique merchants in each category**

# %%
 inflows[['category','memo']].groupby('category').nunique()
# Out:
#                        memo
# category
# DEPOSIT                   1
# EXTERNAL_TRANSFER         1
# INSURANCE                 1
# INVESTMENT_INCOME         1
# LOAN                      1
# MISCELLANEOUS             1
# OTHER_BENEFITS            1
# PAYCHECK                  1
# PAYCHECK_PLACEHOLDER      1
# REFUND                    1
# SELF_TRANSFER             1
# SMALL_DOLLAR_ADVANCE      1
# TAX                       1
# UNEMPLOYMENT_BENEFITS     1

# %% [markdown]
# *outflows*

# %%
outflows['memo'].value_counts()
# Out:
# memo
# EXTERNAL_TRANSFER                                                                    320998
# AUTOMOTIVE                                                                           208579
# ATM_CASH                                                                             117651
# UNCATEGORIZED                                                                        117409
# LOAN                                                                                  90945
#                                                                                       ...
# Par Gators Dockside -                                                                     1
# Chilis Mandarin                                                                           1
# Chilis Bay Meadows                                                                        1
# Southside Liquor                                                                          1
# POS WITHDRAWALWAL-MART #XXXX XXXX E MCKELLIPS RD MESA AZ  Card 15 #XXXX  MCC XXXX         1
# Name: count, Length: 528786, dtype: int64

# %%
list(outflows['category'].unique())
# Out:
# ['LOAN',
#  'ATM_CASH',
#  'FOOD_AND_BEVERAGES',
#  'ENTERTAINMENT',
#  'GENERAL_MERCHANDISE',
#  'ESSENTIAL_SERVICES',
#  'GROCERIES',
#  'EXTERNAL_TRANSFER',
#  'AUTOMOTIVE',
#  'UNCATEGORIZED',
#  'CREDIT_CARD_PAYMENT',
#  'SELF_TRANSFER',
#  'PETS',
#  'HEALTHCARE_MEDICAL',
#  'INSURANCE',
#  'ACCOUNT_FEES',
#  'HOME_IMPROVEMENT',
#  'TRAVEL',
#  'MORTGAGE',
#  'OVERDRAFT',
#  'EDUCATION',
#  'RENT',
#  'TAX',
#  'CHILD_DEPENDENTS',
#  'GIFTS_DONATIONS',
#  'BILLS_UTILITIES',
#  'PAYCHECK',
#  'BNPL',
#  'AUTO_LOAN']

# %%
outflows[outflows['category'] == 'BILLS_UTILITIES']['memo'].unique()
# Out:
# array(['BILLS_UTILITIES'], dtype=object)

# %% [markdown]
# **Uncategorized Category**

# %%
outflows[outflows['category'] == 'UNCATEGORIZED']
# Out:
#          prism_consumer_id prism_account_id           memo  amount  \
# 27                       0            acc_0  UNCATEGORIZED  310.64
# 65                       0            acc_0  UNCATEGORIZED  150.00
# 75                       0            acc_0  UNCATEGORIZED    2.20
# 84                       0            acc_0  UNCATEGORIZED  405.65
# 119                      0            acc_0  UNCATEGORIZED  547.84
# ...                    ...              ...            ...     ...
# 2597446               5941         acc_9524  UNCATEGORIZED  251.51
# 2597463               5941         acc_9524  UNCATEGORIZED  804.27
# 2597467               5941         acc_9524  UNCATEGORIZED   39.64
# 2597472               5941         acc_9524  UNCATEGORIZED    0.00
# 2597487               5941         acc_9524  UNCATEGORIZED   35.13
#
#         posted_date       category
# 27       2022-02-22  UNCATEGORIZED
# 65       2022-03-11  UNCATEGORIZED
# 75       2022-08-01  UNCATEGORIZED
# 84       2022-03-29  UNCATEGORIZED
# 119      2022-08-23  UNCATEGORIZED
# ...             ...            ...
# 2597446  2023-01-13  UNCATEGORIZED
# 2597463  2023-01-18  UNCATEGORIZED
# 2597467  2023-01-19  UNCATEGORIZED
# 2597472  2023-01-20  UNCATEGORIZED
# 2597487  2023-01-25  UNCATEGORIZED
#
# [117409 rows x 6 columns]

# %%
outflows[['category','memo']].groupby('category').nunique()
# Out:
#                        memo
# category
# ACCOUNT_FEES              1
# ATM_CASH                  1
# AUTOMOTIVE                1
# AUTO_LOAN                 1
# BILLS_UTILITIES           1
# BNPL                      1
# CHILD_DEPENDENTS          1
# CREDIT_CARD_PAYMENT       1
# EDUCATION              2122
# ENTERTAINMENT             1
# ESSENTIAL_SERVICES        1
# EXTERNAL_TRANSFER         1
# FOOD_AND_BEVERAGES   213794
# GENERAL_MERCHANDISE  217779
# GIFTS_DONATIONS           1
# GROCERIES             71174
# HEALTHCARE_MEDICAL        1
# HOME_IMPROVEMENT          1
# INSURANCE                 1
# LOAN                      1
# MORTGAGE                174
# OVERDRAFT               844
# PAYCHECK                  1
# PETS                   4421
# RENT                   1776
# SELF_TRANSFER             1
# TAX                       1
# TRAVEL                16683
# UNCATEGORIZED             1

# %%
outflows['memo'].value_counts()
# Out:
# memo
# EXTERNAL_TRANSFER                                                                    320998
# AUTOMOTIVE                                                                           208579
# ATM_CASH                                                                             117651
# UNCATEGORIZED                                                                        117409
# LOAN                                                                                  90945
#                                                                                       ...
# Par Gators Dockside -                                                                     1
# Chilis Mandarin                                                                           1
# Chilis Bay Meadows                                                                        1
# Southside Liquor                                                                          1
# POS WITHDRAWALWAL-MART #XXXX XXXX E MCKELLIPS RD MESA AZ  Card 15 #XXXX  MCC XXXX         1
# Name: count, Length: 528786, dtype: int64

# %%
list(outflows['category'].unique())
# Out:
# ['LOAN',
#  'ATM_CASH',
#  'FOOD_AND_BEVERAGES',
#  'ENTERTAINMENT',
#  'GENERAL_MERCHANDISE',
#  'ESSENTIAL_SERVICES',
#  'GROCERIES',
#  'EXTERNAL_TRANSFER',
#  'AUTOMOTIVE',
#  'UNCATEGORIZED',
#  'CREDIT_CARD_PAYMENT',
#  'SELF_TRANSFER',
#  'PETS',
#  'HEALTHCARE_MEDICAL',
#  'INSURANCE',
#  'ACCOUNT_FEES',
#  'HOME_IMPROVEMENT',
#  'TRAVEL',
#  'MORTGAGE',
#  'OVERDRAFT',
#  'EDUCATION',
#  'RENT',
#  'TAX',
#  'CHILD_DEPENDENTS',
#  'GIFTS_DONATIONS',
#  'BILLS_UTILITIES',
#  'PAYCHECK',
#  'BNPL',
#  'AUTO_LOAN']

# %%
outflows[outflows['category'] == 'BILLS_UTILITIES']['memo'].unique()
# Out:
# array(['BILLS_UTILITIES'], dtype=object)

# %% [markdown]
# **Uncategorized Transactions**

# %%
outflows[outflows['category'] == 'UNCATEGORIZED']
# Out:
#          prism_consumer_id prism_account_id           memo  amount  \
# 27                       0            acc_0  UNCATEGORIZED  310.64
# 65                       0            acc_0  UNCATEGORIZED  150.00
# 75                       0            acc_0  UNCATEGORIZED    2.20
# 84                       0            acc_0  UNCATEGORIZED  405.65
# 119                      0            acc_0  UNCATEGORIZED  547.84
# ...                    ...              ...            ...     ...
# 2597446               5941         acc_9524  UNCATEGORIZED  251.51
# 2597463               5941         acc_9524  UNCATEGORIZED  804.27
# 2597467               5941         acc_9524  UNCATEGORIZED   39.64
# 2597472               5941         acc_9524  UNCATEGORIZED    0.00
# 2597487               5941         acc_9524  UNCATEGORIZED   35.13
#
#         posted_date       category
# 27       2022-02-22  UNCATEGORIZED
# 65       2022-03-11  UNCATEGORIZED
# 75       2022-08-01  UNCATEGORIZED
# 84       2022-03-29  UNCATEGORIZED
# 119      2022-08-23  UNCATEGORIZED
# ...             ...            ...
# 2597446  2023-01-13  UNCATEGORIZED
# 2597463  2023-01-18  UNCATEGORIZED
# 2597467  2023-01-19  UNCATEGORIZED
# 2597472  2023-01-20  UNCATEGORIZED
# 2597487  2023-01-25  UNCATEGORIZED
#
# [117409 rows x 6 columns]

# %%
outflows[['category','memo']].groupby('category').nunique()
# Out:
#                        memo
# category
# ACCOUNT_FEES              1
# ATM_CASH                  1
# AUTOMOTIVE                1
# AUTO_LOAN                 1
# BILLS_UTILITIES           1
# BNPL                      1
# CHILD_DEPENDENTS          1
# CREDIT_CARD_PAYMENT       1
# EDUCATION              2122
# ENTERTAINMENT             1
# ESSENTIAL_SERVICES        1
# EXTERNAL_TRANSFER         1
# FOOD_AND_BEVERAGES   213794
# GENERAL_MERCHANDISE  217779
# GIFTS_DONATIONS           1
# GROCERIES             71174
# HEALTHCARE_MEDICAL        1
# HOME_IMPROVEMENT          1
# INSURANCE                 1
# LOAN                      1
# MORTGAGE                174
# OVERDRAFT               844
# PAYCHECK                  1
# PETS                   4421
# RENT                   1776
# SELF_TRANSFER             1
# TAX                       1
# TRAVEL                16683
# UNCATEGORIZED             1

# %%
# double checking 

# outflows[outflows['category']=='TAX']

# %%
merchant_cat = ['EDUCATION', 'FOOD_AND_BEVERAGES', 'GENERAL_MERCHANDISE', 'GROCERIES', 'MORTGAGE','OVERDRAFT', 'PETS', 'RENT', 'TRAVEL']

# %%
merchant_df = outflows[outflows['category'].isin(merchant_cat)][['category','memo']].reset_index()
merchant_df
# Out:
#            index             category  \
# 0              2   FOOD_AND_BEVERAGES
# 1              4   FOOD_AND_BEVERAGES
# 2              6  GENERAL_MERCHANDISE
# 3              7   FOOD_AND_BEVERAGES
# 4              8  GENERAL_MERCHANDISE
# ...          ...                  ...
# 1306447  2597457  GENERAL_MERCHANDISE
# 1306448  2597462            EDUCATION
# 1306449  2597465   FOOD_AND_BEVERAGES
# 1306450  2597468   FOOD_AND_BEVERAGES
# 1306451  2597476   FOOD_AND_BEVERAGES
#
#                                                       memo
# 0                TST* Casa Del Rio - Exp Fairlawn OH 09/24
# 1                                       Buffalo Wild Wings
# 2                                          Oculus CA 04/16
# 3                              LOS GIRASOLES STOW OH 03/08
# 4                                BUZZIS LAUNDRY 1 OH 03/28
# ...                                                    ...
# 1306447  DEBIT CARD WITHDRAWAL PURCHASEAmazon Prime*TI4...
# 1306448  POS WITHDRAWALAZ LOT QUIKTRIP XXXX XXXX E INDI...
# 1306449  POS WITHDRAWALWAL-MART #XXXX XXXX E MCKELLIPS ...
# 1306450  WITHDRAWAL Salt River ProjeTYPE: ONLINE PMT CO...
# 1306451  POS WITHDRAWALFRYS-FOOD-DRG #1 435 S. E MESA A...
#
# [1306452 rows x 3 columns]

# %%
merchant_df.groupby(['category','memo']).count().sort_values(by=['category','index'], ascending=False).groupby('category').head(3)
# Out:
#                                                                         index
# category            memo
# TRAVEL              Uber                                                 7989
#                     Uber Eats                                            5691
#                     Lyft                                                 4648
# RENT                SOUTHERN INVESTO WEB PMTS                              47
#                     NEWREZ-SHELLPOIN WEB PMTS XXXXXXXXXX WEB ID: XX...     37
#                     CHECKCARD XXXX GRACELAND RENTAL XXX-XXXXXXX KY ...     30
# PETS                PetSmart                                             1450
#                     CHEWY.COM                                             255
#                     Pet Supplies Plus                                     228
# OVERDRAFT           Overdraft Item Fee                                    374
#                     OVERDRAFT ITEM CHARGE                                 191
#                     OVERDRAFT PROTECTION TO XXXXXXXXXXXXXX                180
# MORTGAGE            HUNTINGTON MORTG ONLINE PMT XXXXXX                     52
#                     FREEDOM MTG PYMTS                                      45
#                     WELLS FARGO HOME MORTGAGE Bill Payment                 35
# GROCERIES           Walmart                                             31619
#                     Kroger                                               8423
#                     Target                                               8343
# GENERAL_MERCHANDISE Amazon                                              31725
#                     7-Eleven                                            11675
#                     Circle K                                            10148
# FOOD_AND_BEVERAGES  McDonald's                                          22670
#                     Starbucks                                           12777
#                     Chick-fil-A                                          7933
# EDUCATION           Teacherspayteachers.com                                90
#                     CHECKCARD XXXX BETMGM PLAY+ LAS VEGAS NV XXXXXX...     82
#                     Mms University Of Maryl                                59

# %% [markdown]
# ## Chosen Categories(5)

# %% [markdown]
# - **FOOD_AND_BEVERAGES**
# - **GENERAL_MERCHANDISE**
# - **GROCERIES**
# - **PETS**
# - **TRAVEL**

# %%
chosen_cat = ['FOOD_AND_BEVERAGES', 'GENERAL_MERCHANDISE', 'GROCERIES', 'PETS', 'TRAVEL']

# %%
chosen_df = outflows[outflows['category'].isin(chosen_cat)][['category','memo']].reset_index()
chosen_df.groupby(['category','memo']).count().sort_values(by=['category','index'], ascending=False).groupby('category').head(3)
# Out:
#                                        index
# category            memo
# TRAVEL              Uber                7989
#                     Uber Eats           5691
#                     Lyft                4648
# PETS                PetSmart            1450
#                     CHEWY.COM            255
#                     Pet Supplies Plus    228
# GROCERIES           Walmart            31619
#                     Kroger              8423
#                     Target              8343
# GENERAL_MERCHANDISE Amazon             31725
#                     7-Eleven           11675
#                     Circle K           10148
# FOOD_AND_BEVERAGES  McDonald's         22670
#                     Starbucks          12777
#                     Chick-fil-A         7933

# %% [markdown]
#  ***Most Common Merchants by Category (Top 3)***

# %% [markdown]
# - **`TRAVEL`** :`Uber, Uber Eats, Lyft`
# -  **`PETS`**  : `PetSmart, CHEWY.COM, Pet Supplies Plus`
# - **`GROCERIES`** : `Walmart, Kroger, Target`
# - **`GENERAL_MERCHANDISE`**: `Amazon, 7-Eleven, Circle K`
# - **`FOOD_AND_BEVERAGES`** : `McDonald's, Starbucks, Chick-fil-a`

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
inflows
# Out:
#         prism_consumer_id prism_account_id               memo   amount  \
# 0                       0            acc_0           PAYCHECK  2477.02
# 1                       0            acc_0  EXTERNAL_TRANSFER   100.00
# 2                       0            acc_0      MISCELLANEOUS     6.29
# 3                       0            acc_0  EXTERNAL_TRANSFER   277.00
# 4                       0            acc_0  EXTERNAL_TRANSFER   100.00
# ...                   ...              ...                ...      ...
# 513110               5941         acc_9524  EXTERNAL_TRANSFER     8.66
# 513111               5941         acc_9524  EXTERNAL_TRANSFER   267.13
# 513112               5941         acc_9524  EXTERNAL_TRANSFER     2.00
# 513113               5941         acc_9524  EXTERNAL_TRANSFER   207.16
# 513114               5941         acc_9524  EXTERNAL_TRANSFER   281.71
#
#        posted_date           category
# 0       2022-03-18           PAYCHECK
# 1       2022-10-25  EXTERNAL_TRANSFER
# 2       2022-08-26      MISCELLANEOUS
# 3       2022-06-03  EXTERNAL_TRANSFER
# 4       2022-07-29  EXTERNAL_TRANSFER
# ...            ...                ...
# 513110  2023-01-21  EXTERNAL_TRANSFER
# 513111  2023-01-23  EXTERNAL_TRANSFER
# 513112  2023-01-24  EXTERNAL_TRANSFER
# 513113  2023-01-24  EXTERNAL_TRANSFER
# 513114  2023-01-25  EXTERNAL_TRANSFER
#
# [513115 rows x 6 columns]

# %%
inflows_consumers = inflows['prism_consumer_id'].unique()
inflows_consumers
# Out:
# array([   0,    2,    4, ..., 5939, 5940, 5941])

# %%
in_train_users, in_test_users = train_test_split(inflows_consumers, test_size=0.2)#, random_state=42)
len(in_train_users), len(in_test_users)
# Out:
# (2379, 595)

# %%
595/2379
# Out:
# 0.25010508617065996

# %%
in_train_df = inflows[inflows['prism_consumer_id'].isin(in_train_users)]
in_test_df = inflows[inflows['prism_consumer_id'].isin(in_test_users)]

# %%
in_train_df
# Out:
#         prism_consumer_id prism_account_id               memo   amount  \
# 0                       0            acc_0           PAYCHECK  2477.02
# 1                       0            acc_0  EXTERNAL_TRANSFER   100.00
# 2                       0            acc_0      MISCELLANEOUS     6.29
# 3                       0            acc_0  EXTERNAL_TRANSFER   277.00
# 4                       0            acc_0  EXTERNAL_TRANSFER   100.00
# ...                   ...              ...                ...      ...
# 513110               5941         acc_9524  EXTERNAL_TRANSFER     8.66
# 513111               5941         acc_9524  EXTERNAL_TRANSFER   267.13
# 513112               5941         acc_9524  EXTERNAL_TRANSFER     2.00
# 513113               5941         acc_9524  EXTERNAL_TRANSFER   207.16
# 513114               5941         acc_9524  EXTERNAL_TRANSFER   281.71
#
#        posted_date           category
# 0       2022-03-18           PAYCHECK
# 1       2022-10-25  EXTERNAL_TRANSFER
# 2       2022-08-26      MISCELLANEOUS
# 3       2022-06-03  EXTERNAL_TRANSFER
# 4       2022-07-29  EXTERNAL_TRANSFER
# ...            ...                ...
# 513110  2023-01-21  EXTERNAL_TRANSFER
# 513111  2023-01-23  EXTERNAL_TRANSFER
# 513112  2023-01-24  EXTERNAL_TRANSFER
# 513113  2023-01-24  EXTERNAL_TRANSFER
# 513114  2023-01-25  EXTERNAL_TRANSFER
#
# [413406 rows x 6 columns]

# %%
in_test_df
# Out:
#         prism_consumer_id prism_account_id               memo   amount  \
# 485                     9           acc_18     OTHER_BENEFITS  1763.71
# 486                     9           acc_19      MISCELLANEOUS    24.69
# 487                     9           acc_18  EXTERNAL_TRANSFER    44.97
# 488                     9           acc_20      SELF_TRANSFER   100.00
# 489                     9           acc_19      MISCELLANEOUS    26.79
# ...                   ...              ...                ...      ...
# 512373               5939         acc_9522            DEPOSIT   512.00
# 512374               5939         acc_9522             REFUND   107.35
# 512375               5939         acc_9522            DEPOSIT   576.00
# 512376               5939         acc_9522            DEPOSIT    95.34
# 512377               5939         acc_9522  EXTERNAL_TRANSFER    15.72
#
#        posted_date           category
# 485     2021-04-01     OTHER_BENEFITS
# 486     2019-02-12      MISCELLANEOUS
# 487     2021-03-05  EXTERNAL_TRANSFER
# 488     2019-02-11      SELF_TRANSFER
# 489     2019-04-09      MISCELLANEOUS
# ...            ...                ...
# 512373  2022-12-05            DEPOSIT
# 512374  2022-12-13             REFUND
# 512375  2023-01-03            DEPOSIT
# 512376  2023-01-18            DEPOSIT
# 512377  2023-01-27  EXTERNAL_TRANSFER
#
# [99709 rows x 6 columns]

# %%
len(in_train_df), len(in_test_df)
# Out:
# (413406, 99709)

# %%
99026/414089
# Out:
# 0.2391418269985438

# %%
in_train_df.groupby('prism_consumer_id').size().mean(), in_test_df.groupby('prism_consumer_id').size().mean()
# Out:
# (173.77301387137453, 167.5781512605042)

# %%
in_train_df['amount'].mean(), in_test_df['amount'].mean()
# Out:
# (742.7381076955828, 701.3720024270625)

# %%
in_train_df['amount'].median(), in_test_df['amount'].median()
# Out:
# (100.0, 100.0)

# %% [markdown]
# *outflows*

# %%
outflows_consumers = outflows['prism_consumer_id'].unique()
outflows_consumers
# Out:
# array([   0,    2,    4, ..., 5939, 5940, 5941])

# %%
out_train_users, out_test_users = train_test_split(outflows_consumers, test_size=0.2, random_state=42)
len(out_train_users), len(out_test_users)
# Out:
# (2374, 594)

# %%
594/2374
# Out:
# 0.2502106149957877

# %%
out_train_df = outflows[outflows['prism_consumer_id'].isin(out_train_users)]
out_test_df = outflows[outflows['prism_consumer_id'].isin(out_test_users)]
len(out_train_df), len(out_test_df)
# Out:
# (2097805, 499683)

# %%
len(out_test_df)/len(out_train_df)
# Out:
# 0.23819325437779013

# %%
out_train_df.groupby('prism_consumer_id').size().mean(), out_test_df.groupby('prism_consumer_id').size().mean()
# Out:
# (883.6583824768323, 841.2171717171717)

# %%
out_train_df['amount'].mean(), out_test_df['amount'].mean()
# Out:
# (138.0927030586732, 174.65576219323057)

# %%
results = []

for i in range(10):
    consumers = outflows['prism_consumer_id'].unique()
    train_consumers, test_consumers = train_test_split(consumers, test_size=0.2, random_state=i)

    # create train/test
    out_train_df = outflows[outflows['prism_consumer_id'].isin(train_consumers)]
    out_test_df = outflows[outflows['prism_consumer_id'].isin(test_consumers)]

    train_mean = out_train_df['amount'].mean()
    test_mean = out_test_df['amount'].mean()
    
    results.append({
        'run': i+1,
        'train_mean': train_mean,
        'test_mean': test_mean,
        'test_greater_than_train': test_mean > train_mean
    })
results_df = pd.DataFrame(results)
print("test mean > train mean:", results_df['test_greater_than_train'].sum())

results_df
# Out:
# test mean > train mean: 5
#    run  train_mean   test_mean  test_greater_than_train
# 0    1  143.084348  153.033872                     True
# 1    2  145.634828  143.093660                    False
# 2    3  148.333782  132.006570                    False
# 3    4  135.336009  189.045829                     True
# 4    5  146.713798  138.832393                    False
# 5    6  141.546613  159.400710                     True
# 6    7  145.845616  142.237054                    False
# 7    8  148.314072  132.605315                    False
# 8    9  138.849937  168.705635                     True
# 9   10  141.326526  160.931030                     True

# %% [markdown]
# **We split the data at the consumer level so that all transactions from a single consumer are placed entirely in either the training or test set.**

# %% [markdown]
# **The train and test splits appear to be unbiased. In 10 random runs, the test mean was greater than the train mean 5 times, which is roughly half. This indicates that both splits likely represent the same underlying data distribution.**

# %% [markdown]
# ## Cosine Similarity Tests

# %%
# Group by category to test for overall similarity between train & test groups
# Gets vector (Series) of average spending for category
in_train_profile = in_train_df.groupby('category')['amount'].mean()
in_test_profile = in_test_df.groupby('category')['amount'].mean()

# %%
# If there are categories in one but not the other, fill the missing category in with 0
in_train_profile, in_test_profile = in_train_profile.align(in_test_profile, fill_value=0)

# %%
in_similarity = cosine_similarity(in_train_profile.values.reshape(1,-1), in_test_profile.values.reshape(1,-1))
in_similarity
# Out:
# array([[0.91512213]])

# %%
out_train_profile = out_train_df.groupby('category')['amount'].mean()
out_test_profile = out_test_df.groupby('category')['amount'].mean()

# %%
out_train_profile, out_test_profile = out_train_profile.align(out_test_profile, fill_value=0)

# %%
out_similarity = cosine_similarity(out_train_profile.values.reshape(1,-1), out_test_profile.values.reshape(1,-1))
out_similarity
# Out:
# array([[0.91783205]])

# %% [markdown]
# - **cos(180) = -1 --> vectors are opposites (vectors go in opposite directions)**
#
# - **cos(90) = 0 --> vectors are completely unrelated (vectors are orthogonal)**
#
# - **cos(0) = 1 --> vectors are highly related (vectors are pointing in the same direction)**
#
# - **Cosine similarities for both inflows and outflows are both > 0.9 --> highly similar -> Spending patterns across the train and test sets for both inflows and outflows are similar**
